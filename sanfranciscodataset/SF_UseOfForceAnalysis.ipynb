# %% [markdown]
# In the following notebook, we will be analyzing police use of force data in San Francisco. Raw data can be found [here](https://www.muckrock.com/foi/san-francisco-141/police-use-of-force-data-san-francisco-police-department-93028/#comms)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns

# %%
#Read in data
# %cd /home/kishen/Documents/SFBrigade/datasci-police-budget/data/raw_data

forceType= pd.read_csv('UseOfForce - Force Type.csv',parse_dates=['UOF DATE'])
incident= pd.read_csv('UseOfForce - Incident.csv', parse_dates=['UOF DATE'])
subject= pd.read_csv('UseOfForce - Subject.csv', parse_dates=['UOF DATE'])
# Out:
# /home/kishen/Documents/SFBrigade/datasci-police-budget/data/raw_data

# %% [markdown]
# ## Incident Analysis

# %%
#Preview incident data
display(incident.shape)
incident.head()
# Out:
# (6250, 7)
#   INCIDENT NUMBER REPORT NUMBER   UOF DATE INCIDENT TIME LOCATION ADDRESS  \
# 0   UOF-2015-0034     150000102 2015-01-01           NaN      NaN     NaN
# 1   UOF-2015-0003     150003128 2015-01-02           NaN      NaN     NaN
# 2   UOF-2015-0010     150003071 2015-01-02           NaN      NaN     NaN
# 3   UOF-2015-0004     150004916 2015-01-03           NaN      NaN     NaN
# 4   UOF-2015-0005     150008112 2015-01-03           NaN      NaN     NaN
#
#    DISTRICT
# 0   Central
# 1  Southern
# 2   Bayview
# 3  Southern
# 4  Southern

# %%
#Extract month/year data from UOF DATE
incident.loc[:,'monthYear']= incident['UOF DATE'].dt.to_period('M')

#Plot incidents counts by monthYear
incidentCounts= incident.groupby('monthYear')['INCIDENT NUMBER'].count().reset_index()
incidentCounts.columns= ['monthYear','incidentsCount']

incidentCounts.plot(x= 'monthYear', y= 'incidentsCount',
                   figsize= (10,7), legend= False)

plt.title('Use of Force Incidents Reported in SF (2015-2020)')
plt.xlabel('')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ## Subject Analysis

# %%
#Preview subject data
display(subject.shape)
subject.head()
# Out:
# (7074, 12)
#   INCIDENT NUMBER REPORT NUMBER   UOF DATE  SUBJECT NUMBER SUBJECT RACE  \
# 0   UOF-2015-0034     150000102 2015-01-01             NaN          NaN
# 1   UOF-2015-0003     150003128 2015-01-02             NaN          NaN
# 2   UOF-2015-0010     150003071 2015-01-02             NaN          NaN
# 3   UOF-2015-0004     150004916 2015-01-03             NaN          NaN
# 4   UOF-2015-0005     150008112 2015-01-03             NaN          NaN
#
#   SUBJECT AGE SUBJECT SEX WEAPON TYPE TYPE OF WEAPON(OTHER) COMPLAINT OF PAIN  \
# 0         NaN         NaN         NaN                   NaN               NaN
# 1         NaN         NaN         NaN                   NaN               NaN
# 2         NaN         NaN         NaN                   NaN               NaN
# 3         NaN         NaN         NaN                   NaN               NaN
# 4         NaN         NaN         NaN                   NaN               NaN
#
#   SUBJECT INJURED CHARGES
# 0             NaN     NaN
# 1             NaN     NaN
# 2             NaN     NaN
# 3             NaN     NaN
# 4             NaN     NaN

# %%
#Prep data


#Extract month/year data from UOF DATE
subject.loc[:,'monthYear']= subject['UOF DATE'].dt.to_period('M')

# %%
#Plot subject race counts by monthYear
raceCounts= subject.groupby(['monthYear','SUBJECT RACE'])['REPORT NUMBER'].count().reset_index()
raceCounts.columns= ['monthYear','race','count']

# %%
#Plot counts of incidents reported by race
demographics= list(raceCounts.race.unique())

f, ax= plt.subplots(figsize= (15,7))

for x, i in zip(demographics, range(len(demographics) - 1)):
    raceCounts.loc[raceCounts['race']== str(demographics[i])].plot(x= 'monthYear', y='count', 
                                                          label = x, ax=ax)
    
ax.legend(shadow= True)

# %% [markdown]
# ## Force Type Analysis

# %%
#Preview forceType data
display(forceType.shape)
forceType.head()
# Out:
# (13424, 7)
#     UOF DATE INCIDENT NUMBER REPORT NUMBER  EMPLOYEE NUMBER  SUBJECT NUMBER  \
# 0 2015-01-01   UOF-2015-0034     150000102          17169.0             NaN
# 1 2015-01-02   UOF-2015-0003     150003128          12294.0             NaN
# 2 2015-01-02   UOF-2015-0003     150003128          13423.0             NaN
# 3 2015-01-02   UOF-2015-0010     150003071          10782.0             NaN
# 4 2015-01-02   UOF-2015-0010     150003071          12281.0             NaN
#
#   FORCE DESC FORCE USED OTHER
# 0    UNKNOWN              NaN
# 1    UNKNOWN              NaN
# 2    UNKNOWN              NaN
# 3    UNKNOWN              NaN
# 4    UNKNOWN              NaN

# %%
forceType['FORCE DESC'].unique()
# Out:
# array(['UNKNOWN', 'Firearm', 'OC', 'Pointing of Firearms',
#        'Strike by Object/Fist', 'ERIW', 'Physical Control',
#        'Impact Weapon', 'Carotid', 'Other', 'Vehicle Deflection',
#        'Spike Strips', 'K-9'], dtype=object)

# %%
#Merge force type with racial demographics data
merge= forceType.merge(subject, left_on='INCIDENT NUMBER', right_on= 'INCIDENT NUMBER')
merge.head()
# Out:
#   UOF DATE_x INCIDENT NUMBER REPORT NUMBER_x  EMPLOYEE NUMBER  \
# 0 2015-01-01   UOF-2015-0034       150000102          17169.0
# 1 2015-01-02   UOF-2015-0003       150003128          12294.0
# 2 2015-01-02   UOF-2015-0003       150003128          13423.0
# 3 2015-01-02   UOF-2015-0010       150003071          10782.0
# 4 2015-01-02   UOF-2015-0010       150003071          12281.0
#
#    SUBJECT NUMBER_x FORCE DESC FORCE USED OTHER REPORT NUMBER_y UOF DATE_y  \
# 0               NaN    UNKNOWN              NaN       150000102 2015-01-01
# 1               NaN    UNKNOWN              NaN       150003128 2015-01-02
# 2               NaN    UNKNOWN              NaN       150003128 2015-01-02
# 3               NaN    UNKNOWN              NaN       150003071 2015-01-02
# 4               NaN    UNKNOWN              NaN       150003071 2015-01-02
#
#    SUBJECT NUMBER_y SUBJECT RACE SUBJECT AGE SUBJECT SEX WEAPON TYPE  \
# 0               NaN          NaN         NaN         NaN         NaN
# 1               NaN          NaN         NaN         NaN         NaN
# 2               NaN          NaN         NaN         NaN         NaN
# 3               NaN          NaN         NaN         NaN         NaN
# 4               NaN          NaN         NaN         NaN         NaN
#
#   TYPE OF WEAPON(OTHER) COMPLAINT OF PAIN SUBJECT INJURED CHARGES monthYear
# 0                   NaN               NaN             NaN     NaN   2015-01
# 1                   NaN               NaN             NaN     NaN   2015-01
# 2                   NaN               NaN             NaN     NaN   2015-01
# 3                   NaN               NaN             NaN     NaN   2015-01
# 4                   NaN               NaN             NaN     NaN   2015-01

# %%
merge['WEAPON TYPE'].unique()
# Out:
# array([nan, 'Replica Firearm', 'Knife or Edged Weapon', 'Other',
#        'Firearm', 'Firearm; Knife or Edged Weapon', 'Blunt Object',
#        'Blunt Object; Knife or Edged Weapon', 'Knife',
#        'Knife or Edged Weapon; Replica Firearm',
#        'Knife or Edged Weapon; Other',
#        'Knife or Edged Weapon; Blunt Object', 'Blunt Object; Other',
#        'Firearm; Other',
#        'Firearm; Replica Firearm; Knife or Edged Weapon; Blunt Object; Other'],
#       dtype=object)

# %%
#Get counts of incidents by race and type of force used

incidentStats= merge.groupby(['SUBJECT RACE','FORCE DESC'])['INCIDENT NUMBER'].count().reset_index()
incidentStats.columns = ['subjectRace','forceUsed', 'count']

# %%
incidentStats= incidentStats.pivot(index= 'subjectRace', columns='forceUsed', values= 'count')
incidentStats
# Out:
# forceUsed                      Carotid   ERIW  Firearm  Impact Weapon  K-9  \
# subjectRace
# A - Asian or Pacific Islander      2.0    6.0      NaN           33.0  NaN
# B - Black                          7.0   50.0     14.0          148.0  2.0
# H - Hispanic                       3.0  112.0     37.0           59.0  NaN
# I - American Indian                NaN    1.0      1.0            NaN  NaN
# U - Unknown                        NaN    6.0      4.0           15.0  NaN
# W - White                          3.0   51.0     42.0          106.0  NaN
#
# forceUsed                         OC  Other  Physical Control  \
# subjectRace
# A - Asian or Pacific Islander   10.0    NaN             150.0
# B - Black                      104.0   66.0            1113.0
# H - Hispanic                    38.0   19.0             650.0
# I - American Indian              NaN    NaN               3.0
# U - Unknown                      6.0    5.0             120.0
# W - White                       68.0   39.0             945.0
#
# forceUsed                      Pointing of Firearms  Spike Strips  \
# subjectRace
# A - Asian or Pacific Islander                1045.0           2.0
# B - Black                                    6545.0          63.0
# H - Hispanic                                 3243.0           NaN
# I - American Indian                             1.0           NaN
# U - Unknown                                   668.0          10.0
# W - White                                    2720.0           1.0
#
# forceUsed                      Strike by Object/Fist  UNKNOWN  \
# subjectRace
# A - Asian or Pacific Islander                   60.0      1.0
# B - Black                                      506.0      NaN
# H - Hispanic                                   285.0      NaN
# I - American Indian                              NaN      NaN
# U - Unknown                                     38.0      NaN
# W - White                                      335.0      3.0
#
# forceUsed                      Vehicle Deflection
# subjectRace
# A - Asian or Pacific Islander                 NaN
# B - Black                                     6.0
# H - Hispanic                                  NaN
# I - American Indian                           NaN
# U - Unknown                                   NaN
# W - White                                     4.0

# %%
#Subset cols pertaining to firearms
firearms= incidentStats.loc[:,['Pointing of Firearms']]

# %%
#Create pie chart to view proportions of pointing of firearms by racial demo
from matplotlib.gridspec import GridSpec

firearmLabels = firearms['Pointing of Firearms'].sort_values().index 
firearmCounts = firearms['Pointing of Firearms'].sort_values()

plt.figure(1, figsize= (20,10))
the_grid= GridSpec(2,2)

cmap = plt.get_cmap('Spectral')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

plt.subplot(the_grid[0, 1], aspect=1, title='Pointing of Firearms\n(2015 - 2020)')
type_show_ids = plt.pie(firearmCounts, labels=firearmLabels, autopct='%1.1f%%', shadow=True, colors=colors)
plt.show()

# %%
#Subset cols pertaining to use of physical force
pForce= incidentStats.loc[:,['Physical Control', 'Impact Weapon', 'Strike by Object/Fist','Carotid']]
pForce['Total']= pForce.sum(axis=1)

# %%
#Create pie chart to view proportions of use of physical force by racial demo
pForceLabels = pForce['Total'].sort_values().index 
pForceCounts = pForce['Total'].sort_values()

plt.figure(1, figsize= (20,10))
the_grid= GridSpec(2,2)

cmap = plt.get_cmap('Spectral')
colors = [cmap(i) for i in np.linspace(0, 1, 8)]

plt.subplot(the_grid[0, 1], aspect=1, title='Use of Physical Force\n(2015 - 2020)')
type_show_ids = plt.pie(pForceCounts, labels=pForceLabels, autopct='%1.1f%%', shadow=True, colors=colors)
plt.show()
